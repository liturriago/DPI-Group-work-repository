# %% [markdown]
# **Procesamiento Digital de Imgenes** \\
# Ejercicio: Generar imagenes de colores (RGB) \\
# **Nombre:** Óscar Adolfo Tamayo Vélez \\
# Universidad Nacional de Colombia - Sede Manizales

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
imagen = np.zeros((1080, 1920, 3), dtype = int)

fig = plt.figure(figsize=(16,20))                                   #Se configuran las dimensiones de la imagen de salida modificada
ax1 = plt.subplot2grid((8,25),(0,0),rowspan= 1,colspan = 4)
ax2 = plt.subplot2grid((8,25),(0,5),rowspan= 1,colspan = 4)
ax3 = plt.subplot2grid((8,25),(0,10),rowspan= 1,colspan = 4)
ax4 = plt.subplot2grid((8,25),(0,15),rowspan= 1,colspan = 4)
ax5 = plt.subplot2grid((8,25),(0,20),rowspan= 1,colspan = 4)
ax6 = plt.subplot2grid((8,25),(1,0),rowspan= 1,colspan = 4)
ax7 = plt.subplot2grid((8,25),(1,5),rowspan= 1,colspan = 4)
ax8 = plt.subplot2grid((8,25),(1,10),rowspan= 1,colspan = 4)
ax9 = plt.subplot2grid((8,25),(1,15),rowspan= 1,colspan = 4)
ax10 = plt.subplot2grid((8,25),(1,20),rowspan= 1,colspan = 4)

white = imagen + [255, 255, 255]
black = imagen + [0, 0, 0]
red = imagen + [255, 0, 0]
green = imagen + [0, 255, 0]
blue = imagen + [0, 0, 255]
yellow = imagen + [255, 255, 0]
cyan = imagen + [0, 255, 255]
purple = imagen + [255, 0, 255]
gray = imagen + [100, 100, 100]
marron = imagen + [160, 82, 45]

ax1.imshow(white)
ax2.imshow(black)
ax3.imshow(red)
ax4.imshow(green)
ax5.imshow(blue)
ax6.imshow(yellow)
ax7.imshow(cyan)
ax8.imshow(purple)
ax9.imshow(gray)
ax10.imshow(marron)
