# %%
  from cv2 import imread
  import matplotlib.pyplot as plt
  import numpy as np

# %%
FILEID = "12ba7E_rxvkKXSElYQeOrZPBxpWQyv2QO"
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id='$FILEID -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id="$FILEID -O Numpy_wolf_crop.jpeg && rm -rf /tmp/cookies.txt > /dev/null
# Out:
# --2022-04-07 23:58:03--  https://docs.google.com/uc?export=download&confirm=&id=12ba7E_rxvkKXSElYQeOrZPBxpWQyv2QO
# Resolving docs.google.com (docs.google.com)... 74.125.31.139, 74.125.31.138, 74.125.31.113, ...
# Connecting to docs.google.com (docs.google.com)|74.125.31.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-14-60-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/envbdf12lhji8pj689goq6fv9bbsf3e8/1649375850000/09711457892284675029/*/12ba7E_rxvkKXSElYQeOrZPBxpWQyv2QO?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2022-04-07 23:58:03--  https://doc-14-60-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/envbdf12lhji8pj689goq6fv9bbsf3e8/1649375850000/09711457892284675029/*/12ba7E_rxvkKXSElYQeOrZPBxpWQyv2QO?e=download
# Resolving doc-14-60-docs.googleusercontent.com (doc-14-60-docs.googleusercontent.com)... 173.194.215.132, 2607:f8b0:400c:c0c::84
# Connecting to doc-14-60-docs.googleusercontent.com (doc-14-60-docs.googleusercontent.com)|173.194.215.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 334669 (327K) [image/jpeg]
# Saving to: ‘Numpy_wolf_crop.jpeg’
#
# Numpy_wolf_crop.jpe 100%[===================>] 326.83K  --.-KB/s    in 0.004s
#
# 2022-04-07 23:58:04 (72.9 MB/s) - ‘Numpy_wolf_crop.jpeg’ saved [334669/334669]

# %%
img = imread('./Numpy_wolf_crop.jpeg', 0) #Read image in grayscale and return in a numpy array
print('Original Image shape = ',img.shape)
print('Maximun pixel value (white) = ',img.max())
fig = plt.figure(figsize=(10,10))
plt.imshow(img, cmap='gray')
plt.colorbar(orientation='horizontal', ticks=[img.min(), img.max()])
# Out:
# Original Image shape =  (1212, 2416)
# Maximun pixel value (white) =  255

# %%
new_img = np.delete(img,np.where((np.mean(img,0))==img.max()),1)#R{NxP}
new_img = np.delete(new_img,np.where((np.mean(img,1))==img.max()),0)#R{NxP}
new_img.shape
# Out:
# (992, 2056)

# %%
fig = plt.figure(figsize=(10,10))
plt.imshow(new_img, cmap='gray')
plt.colorbar(orientation='horizontal', ticks=[img.min(), img.max()])
print('New Image shape (cropped) = ',new_img.shape)
# Out:
# New Image shape (cropped) =  (992, 2056)
